# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import rcParams
from scipy.optimize import curve_fit
from scipy.ndimage import gaussian_filter

import sys
fpath = '/Users/LingxinW/Box/Wang/PythonStuff'
sys.path.append(fpath)
import heka_reader

# %%
cd ~/Box/Wang/Ephys_recording/ALM_ephys/recordingfiles
# Out:
# C:\Users\LingxinW\Box\Wang\Ephys_recording\ALM_ephys\recordingfiles

# %%
myfile = heka_reader.Bundle ('190918.dat') # pick one specific recording file

# %%
# extract data for stimulation
#stim_trap = []
#for j in range (0,5):

# Here is to analysis the Trapzoidal data in TrapRate X10
    
x1 = np.arange(len(myfile.data[2,21,0,1]))/10000
x2 = np.arange(len(myfile.data[2,21,1,1]))/10000
x3 = np.arange(len(myfile.data[2,21,2,1]))/10000
x4 = np.arange(len(myfile.data[2,21,3,1]))/10000
#x5 = np.arange(len(myfile.data[2,21,4,1]))/10000
    
stim_trap_swp1 = myfile.data[2,21,0,1]
stim_trap_swp2 = myfile.data[2,21,1,1]
stim_trap_swp3 = myfile.data[2,21,2,1]
stim_trap_swp4 = myfile.data[2,21,3,1]
#stim_trap_swp5 = myfile.data[2,21,4,1]

# creat empty list of 1-5 sweeps and later put all three sweeps into this empty list

sw1 = []
sw2 = []
sw3 = []
sw4 = []
sw5 = []

# create a for loop to collect 1-4 sweeps in three series
n=[21,26,31]
for i in n:
    sw1.append(myfile.data[2,i,0,0]*1000000000000)
    sw2.append(myfile.data[2,i,1,0]*1000000000000)
    sw3.append(myfile.data[2,i,2,0]*1000000000000)
    sw4.append(myfile.data[2,i,3,0]*1000000000000)
   # sw5.append(myfile.data[2,i,4,0]*1000000000000)
  
# Now calculate the mean of three repeats by averaging the nested lists (lists in lists)
# here I just want to print to give one expample of the mean of three same sweeps, here sweep #1.
xc1 = np.arange(len(myfile.data[2,21,0,0]))/10000
xc2 = np.arange(len(myfile.data[2,21,1,0]))/10000
xc3 = np.arange(len(myfile.data[2,21,2,0]))/10000
xc4 = np.arange(len(myfile.data[2,21,3,0]))/10000
#xc5 = np.arange(len(myfile.data[2,21,4,0]))/10000

sw1_mean = (sw1[0]+sw1[1]+sw1[2])/3
sw2_mean = (sw2[0]+sw2[1]+sw2[2])/3
sw3_mean = (sw3[0]+sw3[1]+sw3[2])/3
sw4_mean = (sw4[0]+sw4[1]+sw4[2])/3
#sw5_mean = (sw5[0]+sw5[1]+sw5[2])/3

print (sw1_mean)
# Out:
# [ 0.02085729  0.85514893  0.93857809 ...  0.18771562 -0.35457395
#  -0.56314685]

# %%
fig, ax = plt.subplots (figsize=(25,10)) # set figure size
ax.spines ['top'].set_visible (False)
ax.spines ['right'].set_visible (False)
ax.set_xlabel ('time (s)', fontsize = 30)
ax.set_ylabel ('MRC (pA)', fontsize = 30)

#plt.plot (x, y1, 'o', markersize = 8, color = 'b')
plt.plot (x1, stim_trap_swp1, 'r-', lw=4)
plt.plot (x2, stim_trap_swp2, 'r-', lw=4)
plt.plot (x3, stim_trap_swp3, 'r-', lw=4)
plt.plot (x4, stim_trap_swp4, 'r-', lw=4)
#plt.plot (x5, stim_trap_swp5, 'r-', lw=4)

plt.plot (xc1, gaussian_filter (sw1_mean, 3), 'g-', lw=4)
plt.plot (xc2, gaussian_filter (sw2_mean, 3), 'g-', lw=4)
plt.plot (xc3, gaussian_filter (sw3_mean, 3), 'g-', lw=4)
plt.plot (xc4, gaussian_filter (sw4_mean, 3), 'g-', lw=4)
#plt.plot (xc5, gaussian_filter (sw5_mean, 3), 'g-', lw=4)

# %%
# Here is to analysis the Trapzoidal data in TrapRate X5
    
x1 = np.arange(len(myfile.data[2,22,0,1]))/10000
x2 = np.arange(len(myfile.data[2,22,1,1]))/10000
x3 = np.arange(len(myfile.data[2,22,2,1]))/10000
x4 = np.arange(len(myfile.data[2,22,3,1]))/10000
x5 = np.arange(len(myfile.data[2,22,4,1]))/10000
    
stim_trap_swp1 = myfile.data[2,22,0,1]
stim_trap_swp2 = myfile.data[2,22,1,1]
stim_trap_swp3 = myfile.data[2,22,2,1]
stim_trap_swp4 = myfile.data[2,22,3,1]
stim_trap_swp5 = myfile.data[2,22,4,1]

# creat empty list of 1-5 sweeps and later put all three sweeps into this empty list

sw1 = []
sw2 = []
sw3 = []
sw4 = []
sw5 = []

# create a for loop to collect 1-4 sweeps in three series
n=[22,27,32]
for i in n:
    sw1.append(myfile.data[2,i,0,0]*1000000000000)
    sw2.append(myfile.data[2,i,1,0]*1000000000000)
    sw3.append(myfile.data[2,i,2,0]*1000000000000)
    sw4.append(myfile.data[2,i,3,0]*1000000000000)
    sw5.append(myfile.data[2,i,4,0]*1000000000000)
  
# Now calculate the mean of three repeats by averaging the nested lists (lists in lists)
# here I just want to print to give one expample of the mean of three same sweeps, here sweep #1.
xc1 = np.arange(len(myfile.data[2,22,0,0]))/10000
xc2 = np.arange(len(myfile.data[2,22,1,0]))/10000
xc3 = np.arange(len(myfile.data[2,22,2,0]))/10000
xc4 = np.arange(len(myfile.data[2,22,3,0]))/10000
xc5 = np.arange(len(myfile.data[2,22,4,0]))/10000

sw1_mean = (sw1[0]+sw1[1]+sw1[2])/3
sw2_mean = (sw2[0]+sw2[1]+sw2[2])/3
sw3_mean = (sw3[0]+sw3[1]+sw3[2])/3
sw4_mean = (sw4[0]+sw4[1]+sw4[2])/3
sw5_mean = (sw5[0]+sw5[1]+sw5[2])/3

print (sw1_mean)
# Out:
# [ 0.2294302   0.18771562  0.2294302  ...  0.52143227  0.56314685
#  -0.18771562]

# %%
fig, ax = plt.subplots (figsize=(25,10)) # set figure size
ax.spines ['top'].set_visible (False)
ax.spines ['right'].set_visible (False)
ax.set_xlabel ('time (s)', fontsize = 30)
ax.set_ylabel ('MRC (pA)', fontsize = 30)

#plt.plot (x, y1, 'o', markersize = 8, color = 'b')
plt.plot (x1, stim_trap_swp1, 'r-', lw=4)
plt.plot (x2, stim_trap_swp2, 'r-', lw=4)
plt.plot (x3, stim_trap_swp3, 'r-', lw=4)
plt.plot (x4, stim_trap_swp4, 'r-', lw=4)
plt.plot (x5, stim_trap_swp5, 'r-', lw=4)

plt.plot (xc1, gaussian_filter (sw1_mean, 3), 'g-', lw=4)
plt.plot (xc2, gaussian_filter (sw2_mean, 3), 'g-', lw=4)
plt.plot (xc3, gaussian_filter (sw3_mean, 3), 'g-', lw=4)
plt.plot (xc4, gaussian_filter (sw4_mean, 3), 'g-', lw=4)
plt.plot (xc5, gaussian_filter (sw5_mean, 3), 'g-', lw=4)

# %%
# Here is to analysis the Trapzoidal data in TrapRate -25
    
x1 = np.arange(len(myfile.data[2,23,0,1]))/10000
x2 = np.arange(len(myfile.data[2,23,1,1]))/10000
#x3 = np.arange(len(myfile.data[2,22,2,1]))/10000
#x4 = np.arange(len(myfile.data[2,22,3,1]))/10000
#x5 = np.arange(len(myfile.data[2,22,4,1]))/10000
    
stim_trap_swp1 = myfile.data[2,23,0,1]
stim_trap_swp2 = myfile.data[2,23,1,1]
#stim_trap_swp3 = myfile.data[2,23,2,1]
#stim_trap_swp4 = myfile.data[2,22,3,1]
#stim_trap_swp5 = myfile.data[2,22,4,1]

# creat empty list of 1-5 sweeps and later put all three sweeps into this empty list

sw1 = []
sw2 = []
#sw3 = []
#sw4 = []
#sw5 = []

# create a for loop to collect 1-4 sweeps in three series
n=[23,28,33]
for i in n:
    sw1.append(myfile.data[2,i,0,0]*1000000000000)
    sw2.append(myfile.data[2,i,1,0]*1000000000000)
    #sw3.append(myfile.data[2,i,2,0]*1000000000000)
    #sw4.append(myfile.data[2,i,3,0]*1000000000000)
    #sw5.append(myfile.data[2,i,4,0]*1000000000000)
  
# Now calculate the mean of three repeats by averaging the nested lists (lists in lists)
# here I just want to print to give one expample of the mean of three same sweeps, here sweep #1.
xc1 = np.arange(len(myfile.data[2,23,0,0]))/10000
xc2 = np.arange(len(myfile.data[2,23,1,0]))/10000
#xc3 = np.arange(len(myfile.data[2,22,2,0]))/10000
#xc4 = np.arange(len(myfile.data[2,22,3,0]))/10000
#xc5 = np.arange(len(myfile.data[2,22,4,0]))/10000

sw1_mean = (sw1[0]+sw1[1]+sw1[2])/3
sw2_mean = (sw2[0]+sw2[1]+sw2[2])/3
#sw3_mean = (sw3[0]+sw3[1]+sw3[2])/3
#sw4_mean = (sw4[0]+sw4[1]+sw4[2])/3
#sw5_mean = (sw5[0]+sw5[1]+sw5[2])/3

print (sw1_mean)
# Out:
# [ 0.77171976 -0.77171976 -0.73000518 ...  0.73000518  0.6882906
#   0.35457395]

# %%
fig, ax = plt.subplots (figsize=(25,10)) # set figure size
ax.spines ['top'].set_visible (False)
ax.spines ['right'].set_visible (False)
ax.set_xlabel ('time (s)', fontsize = 30)
ax.set_ylabel ('MRC (pA)', fontsize = 30)

#plt.plot (x, y1, 'o', markersize = 8, color = 'b')
plt.plot (x1, stim_trap_swp1, 'r-', lw=4)
plt.plot (x2, stim_trap_swp2, 'r-', lw=4)
#plt.plot (x3, stim_trap_swp3, 'r-', lw=4)
#plt.plot (x4, stim_trap_swp4, 'r-', lw=4)
#plt.plot (x5, stim_trap_swp5, 'r-', lw=4)

plt.plot (xc1, gaussian_filter (sw1_mean, 3), 'g-', lw=4)
plt.plot (xc2, gaussian_filter (sw2_mean, 3), 'g-', lw=4)
#plt.plot (xc3, gaussian_filter (sw3_mean, 3), 'g-', lw=4)
#plt.plot (xc4, gaussian_filter (sw4_mean, 3), 'g-', lw=4)
#plt.plot (xc5, gaussian_filter (sw5_mean, 3), 'g-', lw=4)

# %%
# Here is to analysis the Trapzoidal data in TrapRate X2
    
x1 = np.arange(len(myfile.data[2,24,0,1]))/10000
x2 = np.arange(len(myfile.data[2,24,1,1]))/10000
x3 = np.arange(len(myfile.data[2,24,2,1]))/10000
x4 = np.arange(len(myfile.data[2,24,3,1]))/10000
#x5 = np.arange(len(myfile.data[2,21,4,1]))/10000
    
stim_trap_swp1 = myfile.data[2,24,0,1]
stim_trap_swp2 = myfile.data[2,24,1,1]
stim_trap_swp3 = myfile.data[2,24,2,1]
stim_trap_swp4 = myfile.data[2,24,3,1]
#stim_trap_swp5 = myfile.data[2,21,4,1]

# creat empty list of 1-5 sweeps and later put all three sweeps into this empty list

sw1 = []
sw2 = []
sw3 = []
sw4 = []
sw5 = []

# create a for loop to collect 1-4 sweeps in three series
n=[24,29,34]
for i in n:
    sw1.append(myfile.data[2,i,0,0]*1000000000000)
    sw2.append(myfile.data[2,i,1,0]*1000000000000)
    sw3.append(myfile.data[2,i,2,0]*1000000000000)
    sw4.append(myfile.data[2,i,3,0]*1000000000000)
   # sw5.append(myfile.data[2,i,4,0]*1000000000000)
  
# Now calculate the mean of three repeats by averaging the nested lists (lists in lists)
# here I just want to print to give one expample of the mean of three same sweeps, here sweep #1.
xc1 = np.arange(len(myfile.data[2,24,0,0]))/10000
xc2 = np.arange(len(myfile.data[2,24,1,0]))/10000
xc3 = np.arange(len(myfile.data[2,24,2,0]))/10000
xc4 = np.arange(len(myfile.data[2,24,3,0]))/10000
#xc5 = np.arange(len(myfile.data[2,21,4,0]))/10000

sw1_mean = (sw1[0]+sw1[1]+sw1[2])/3
sw2_mean = (sw2[0]+sw2[1]+sw2[2])/3
sw3_mean = (sw3[0]+sw3[1]+sw3[2])/3
sw4_mean = (sw4[0]+sw4[1]+sw4[2])/3
#sw5_mean = (sw5[0]+sw5[1]+sw5[2])/3

print (sw1_mean)
# Out:
# [0.02085729 0.14600104 0.56314685 ... 0.10428645 0.02085729 0.02085729]

# %%
fig, ax = plt.subplots (figsize=(25,10)) # set figure size
ax.spines ['top'].set_visible (False)
ax.spines ['right'].set_visible (False)
ax.set_xlabel ('time (s)', fontsize = 30)
ax.set_ylabel ('MRC (pA)', fontsize = 30)

#plt.plot (x, y1, 'o', markersize = 8, color = 'b')
plt.plot (x1, stim_trap_swp1, 'r-', lw=4)
plt.plot (x2, stim_trap_swp2, 'r-', lw=4)
plt.plot (x3, stim_trap_swp3, 'r-', lw=4)
plt.plot (x4, stim_trap_swp4, 'r-', lw=4)
#plt.plot (x5, stim_trap_swp5, 'r-', lw=4)

plt.plot (xc1, gaussian_filter (sw1_mean, 3), 'g-', lw=4)
plt.plot (xc2, gaussian_filter (sw2_mean, 3), 'g-', lw=4)
plt.plot (xc3, gaussian_filter (sw3_mean, 3), 'g-', lw=4)
plt.plot (xc4, gaussian_filter (sw4_mean, 3), 'g-', lw=4)
#plt.plot (xc5, gaussian_filter (sw5_mean, 3), 'g-', lw=4)

# %%
# Here is to analysis the Trapzoidal data in TrapRate -1
    
x1 = np.arange(len(myfile.data[2,25,0,1]))/10000
x2 = np.arange(len(myfile.data[2,25,1,1]))/10000
#x3 = np.arange(len(myfile.data[2,22,2,1]))/10000
#x4 = np.arange(len(myfile.data[2,22,3,1]))/10000
#x5 = np.arange(len(myfile.data[2,22,4,1]))/10000
    
stim_trap_swp1 = myfile.data[2,25,0,1]
stim_trap_swp2 = myfile.data[2,25,1,1]
#stim_trap_swp3 = myfile.data[2,23,2,1]
#stim_trap_swp4 = myfile.data[2,22,3,1]
#stim_trap_swp5 = myfile.data[2,22,4,1]

# creat empty list of 1-5 sweeps and later put all three sweeps into this empty list

sw1 = []
sw2 = []
#sw3 = []
#sw4 = []
#sw5 = []

# create a for loop to collect 1-4 sweeps in three series
n=[25,30,35]
for i in n:
    sw1.append(myfile.data[2,i,0,0]*1000000000000)
    sw2.append(myfile.data[2,i,1,0]*1000000000000)
    #sw3.append(myfile.data[2,i,2,0]*1000000000000)
    #sw4.append(myfile.data[2,i,3,0]*1000000000000)
    #sw5.append(myfile.data[2,i,4,0]*1000000000000)
  
# Now calculate the mean of three repeats by averaging the nested lists (lists in lists)
# here I just want to print to give one expample of the mean of three same sweeps, here sweep #1.
xc1 = np.arange(len(myfile.data[2,25,0,0]))/10000
xc2 = np.arange(len(myfile.data[2,25,1,0]))/10000
#xc3 = np.arange(len(myfile.data[2,22,2,0]))/10000
#xc4 = np.arange(len(myfile.data[2,22,3,0]))/10000
#xc5 = np.arange(len(myfile.data[2,22,4,0]))/10000

sw1_mean = (sw1[0]+sw1[1]+sw1[2])/3
sw2_mean = (sw2[0]+sw2[1]+sw2[2])/3
#sw3_mean = (sw3[0]+sw3[1]+sw3[2])/3
#sw4_mean = (sw4[0]+sw4[1]+sw4[2])/3
#sw5_mean = (sw5[0]+sw5[1]+sw5[2])/3

print (sw1_mean)
# Out:
# [ 0.52143227 -0.10428645  0.35457395 ... -0.18771562  0.81343435
#   0.39628853]

# %%
fig, ax = plt.subplots (figsize=(25,10)) # set figure size
ax.spines ['top'].set_visible (False)
ax.spines ['right'].set_visible (False)
ax.set_xlabel ('time (s)', fontsize = 30)
ax.set_ylabel ('MRC (pA)', fontsize = 30)

#plt.plot (x, y1, 'o', markersize = 8, color = 'b')
plt.plot (x1, stim_trap_swp1, 'r-', lw=4)
plt.plot (x2, stim_trap_swp2, 'r-', lw=4)
#plt.plot (x3, stim_trap_swp3, 'r-', lw=4)
#plt.plot (x4, stim_trap_swp4, 'r-', lw=4)
#plt.plot (x5, stim_trap_swp5, 'r-', lw=4)

plt.plot (xc1, gaussian_filter (sw1_mean, 3), 'g-', lw=4)
plt.plot (xc2, gaussian_filter (sw2_mean, 3), 'g-', lw=4)
#plt.plot (xc3, gaussian_filter (sw3_mean, 3), 'g-', lw=4)
#plt.plot (xc4, gaussian_filter (sw4_mean, 3), 'g-', lw=4)
#plt.plot (xc5, gaussian_filter (sw5_mean, 3), 'g-', lw=4)

# %% [markdown]
# # program to analyse the stimulation ramp starting time for ON current

# %%
# TrapRate X5

x1 = np.arange(len(myfile.data[2,22,0,1]))/10000
x2 = np.arange(len(myfile.data[2,22,1,1]))/10000
x3 = np.arange(len(myfile.data[2,22,2,1]))/10000
x4 = np.arange(len(myfile.data[2,22,3,1]))/10000
x5 = np.arange(len(myfile.data[2,22,4,1]))/10000
    
y1=stim_trap_swp1 = myfile.data[2,22,0,1]
y2=stim_trap_swp2 = myfile.data[2,22,1,1]
y3=stim_trap_swp3 = myfile.data[2,22,2,1]
y4=stim_trap_swp4 = myfile.data[2,22,3,1]
y5=stim_trap_swp5 = myfile.data[2,22,4,1]

fig, ax = plt.subplots (figsize=(25,10)) # set figure size
ax.spines ['top'].set_visible (False)
ax.spines ['right'].set_visible (False)
ax.set_xlabel ('time (s)', fontsize = 30)
ax.set_ylabel ('MRC (pA)', fontsize = 30)

#plt.plot (x, y1, 'o', markersize = 8, color = 'b')
plt.plot (x1, stim_trap_swp1, 'r-', lw=4)
plt.plot (x2, stim_trap_swp2, 'r-', lw=4)
plt.plot (x3, stim_trap_swp3, 'r-', lw=4)
plt.plot (x4, stim_trap_swp4, 'r-', lw=4)
plt.plot (x5, stim_trap_swp5, 'r-', lw=4)

# %%
# now calculate the rate of slope using double direvatives 
# the first stimulation is very slow and the rate calculation should be different with others



slopes1= np.diff(y1)
slopes3 = gaussian_filter (slopes1,3) # smooth the slow rate of ramp slope because the changing rate is very slow and 
slopes2= np.diff(slopes3)

fig, ax = plt.subplots()

start = np.argmax(np.diff(gaussian_filter(np.diff(y1[:3000]),3)))/10000 # use gaussian_filter to smooth the noise slopes
print (start)
end = np.argmin(np.diff(gaussian_filter(np.diff(y1[:3000]),3)))/10000
print (end)
ramp_dur = end - start
print(ramp_dur)
step = 8
rate = step/ramp_dur
print(rate)
#ax.plot(x1 ,y1)
#ax.plot(x1 [1:] ,slopes)
ax.plot(slopes1)
#ax.plot(slopes3)
ax.plot(slopes2)
#ax.set_ylim(-1.5,0.005)
#ax.plot(x1 [:2000],d2y)
# Out:
# 0.1499
# 0.1512
# 0.0012999999999999956
# 6153.846153846174

# %%
# loop all traces here 
# same method of calculating the rate of TrapRate x5

y = [y1,y2,y3,y4,y5]
ramp_dur =[]
rate_x5 = []
for i in range (0,5):
    #ramp_dur.append(((np.argmax(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))-np.argmin(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))))/10000)
    rate_x5.append(8/(((np.argmin(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))-np.argmax(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))))/10000))
print (rate_x5)
# Out:
# [63.948840927258196, 320.0, 1568.627450980392, 7272.727272727272, 13333.333333333334]

# %%
# Here is to analysis the Trapzoidal data in TrapRate X10
    
x1 = np.arange(len(myfile.data[2,21,0,1]))/10000
x2 = np.arange(len(myfile.data[2,21,1,1]))/10000
x3 = np.arange(len(myfile.data[2,21,2,1]))/10000
x4 = np.arange(len(myfile.data[2,21,3,1]))/10000
#x5 = np.arange(len(myfile.data[2,21,4,1]))/10000
    
y1=stim_trap_swp1 = myfile.data[2,21,0,1]
y2=stim_trap_swp2 = myfile.data[2,21,1,1]
y3=stim_trap_swp3 = myfile.data[2,21,2,1]
y4=stim_trap_swp4 = myfile.data[2,21,3,1]
#stim_trap_swp5 = myfile.data[2,21,4,1]

fig, ax = plt.subplots (figsize=(25,10)) # set figure size
ax.spines ['top'].set_visible (False)
ax.spines ['right'].set_visible (False)
ax.set_xlabel ('time (s)', fontsize = 30)
ax.set_ylabel ('MRC (pA)', fontsize = 30)

#plt.plot (x, y1, 'o', markersize = 8, color = 'b')
plt.plot (x1, stim_trap_swp1, 'r-', lw=4)
plt.plot (x2, stim_trap_swp2, 'r-', lw=4)
plt.plot (x3, stim_trap_swp3, 'r-', lw=4)
plt.plot (x4, stim_trap_swp4, 'r-', lw=4)
#plt.plot (x5, stim_trap_swp5, 'r-', lw=4)

# %%
# calculate the rate of Trapzoidal stimuli TrapRatex10

y = [y1,y2,y3,y4]
ramp_dur =[]
rate_x10 = []
for i in range (0,4):
    #ramp_dur.append(((np.argmax(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))-np.argmin(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))))/10000)
    rate_x10.append(8/(((np.argmin(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))-np.argmax(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))))/10000))
print (rate_x10)
# Out:
# [80.0, 800.0, 7272.727272727272, 13333.333333333334]

# %%
# here is to plot the Trapzoidal stimuli traces with TrapRate -25

x1 = np.arange(len(myfile.data[2,23,0,1]))/10000
x2 = np.arange(len(myfile.data[2,23,1,1]))/10000
#x3 = np.arange(len(myfile.data[2,22,2,1]))/10000
#x4 = np.arange(len(myfile.data[2,22,3,1]))/10000
#x5 = np.arange(len(myfile.data[2,22,4,1]))/10000
    
y1=stim_trap_swp1 = myfile.data[2,23,0,1]
y2=stim_trap_swp2 = myfile.data[2,23,1,1]
#stim_trap_swp3 = myfile.data[2,23,2,1]
#stim_trap_swp4 = myfile.data[2,22,3,1]
#stim_trap_swp5 = myfile.data[2,22,4,1]

fig, ax = plt.subplots (figsize=(25,10)) # set figure size
ax.spines ['top'].set_visible (False)
ax.spines ['right'].set_visible (False)
ax.set_xlabel ('time (s)', fontsize = 30)
ax.set_ylabel ('MRC (pA)', fontsize = 30)

#plt.plot (x, y1, 'o', markersize = 8, color = 'b')
plt.plot (x1, stim_trap_swp1, 'r-', lw=4)
plt.plot (x2, stim_trap_swp2, 'r-', lw=4)
#plt.plot (x3, stim_trap_swp3, 'r-', lw=4)
#plt.plot (x4, stim_trap_swp4, 'r-', lw=4)
#plt.plot (x5, stim_trap_swp5, 'r-', lw=4)

# %%
# calculate the rate of Trapzoidal stimuli TrapRate-25

y = [y1,y2]
ramp_dur =[]
rate_25 = []
for i in range (0,2):
    #ramp_dur.append(((np.argmax(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))-np.argmin(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))))/10000)
    rate_25.append(8/(((np.argmin(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))-np.argmax(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))))/10000))
print (rate_25)
# Out:
# [80.08008008008008, 106.66666666666667]

# %%
# Here is to analysis the Trapzoidal data in TrapRate X2
    
x1 = np.arange(len(myfile.data[2,24,0,1]))/10000
x2 = np.arange(len(myfile.data[2,24,1,1]))/10000
x3 = np.arange(len(myfile.data[2,24,2,1]))/10000
x4 = np.arange(len(myfile.data[2,24,3,1]))/10000
#x5 = np.arange(len(myfile.data[2,21,4,1]))/10000
    
y1=stim_trap_swp1 = myfile.data[2,24,0,1]
y2=stim_trap_swp2 = myfile.data[2,24,1,1]
y3=stim_trap_swp3 = myfile.data[2,24,2,1]
y4=stim_trap_swp4 = myfile.data[2,24,3,1]
#stim_trap_swp5 = myfile.data[2,21,4,1]

fig, ax = plt.subplots (figsize=(25,10)) # set figure size
ax.spines ['top'].set_visible (False)
ax.spines ['right'].set_visible (False)
ax.set_xlabel ('time (s)', fontsize = 30)
ax.set_ylabel ('MRC (pA)', fontsize = 30)

#plt.plot (x, y1, 'o', markersize = 8, color = 'b')
plt.plot (x1, stim_trap_swp1, 'r-', lw=4)
plt.plot (x2, stim_trap_swp2, 'r-', lw=4)
plt.plot (x3, stim_trap_swp3, 'r-', lw=4)
plt.plot (x4, stim_trap_swp4, 'r-', lw=4)
#plt.plot (x5, stim_trap_swp5, 'r-', lw=4)

# %%
# calculate the rate of Trapzoidal stimuli TrapRate x2

y = [y1,y2,y3,y4]
ramp_dur =[]
rate_x2 = []
for i in range (0,4):
    #ramp_dur.append(((np.argmax(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))-np.argmin(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))))/10000)
    rate_x2.append(8/(((np.argmin(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))-np.argmax(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))))/10000))
print (rate_x2)
# Out:
# [2580.6451612903224, 3809.5238095238096, 7272.727272727272, 13333.333333333334]

# %%
# Here is to analysis the Trapzoidal data in TrapRate -1
    
x1 = np.arange(len(myfile.data[2,25,0,1]))/10000
x2 = np.arange(len(myfile.data[2,25,1,1]))/10000
#x3 = np.arange(len(myfile.data[2,22,2,1]))/10000
#x4 = np.arange(len(myfile.data[2,22,3,1]))/10000
#x5 = np.arange(len(myfile.data[2,22,4,1]))/10000
    
y1=stim_trap_swp1 = myfile.data[2,25,0,1]
y2=stim_trap_swp2 = myfile.data[2,25,1,1]
#stim_trap_swp3 = myfile.data[2,23,2,1]
#stim_trap_swp4 = myfile.data[2,22,3,1]
#stim_trap_swp5 = myfile.data[2,22,4,1]

fig, ax = plt.subplots (figsize=(25,10)) # set figure size
ax.spines ['top'].set_visible (False)
ax.spines ['right'].set_visible (False)
ax.set_xlabel ('time (s)', fontsize = 30)
ax.set_ylabel ('MRC (pA)', fontsize = 30)

#plt.plot (x, y1, 'o', markersize = 8, color = 'b')
plt.plot (x1, stim_trap_swp1, 'r-', lw=4)
plt.plot (x2, stim_trap_swp2, 'r-', lw=4)
#plt.plot (x3, stim_trap_swp3, 'r-', lw=4)
#plt.plot (x4, stim_trap_swp4, 'r-', lw=4)
#plt.plot (x5, stim_trap_swp5, 'r-', lw=4)

# %%
# calculate the rate of Trapzoidal stimuli TrapRate -1

y = [y1,y2]
ramp_dur =[]
rate_1 = []
for i in range (0,2):
    #ramp_dur.append(((np.argmax(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))-np.argmin(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))))/10000)
    rate_1.append(8/(((np.argmin(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))-np.argmax(np.diff(gaussian_filter(np.diff(y[i][:3000]),3)))))/10000))
print (rate_1)
# Out:
# [6153.846153846154, 11428.57142857143]

# %%
print(rate_x10, rate_x5, rate_25, rate_x2, rate_1)
# Out:
# [80.0, 800.0, 7272.727272727272, 13333.333333333334] [63.948840927258196, 320.0, 1568.627450980392, 7272.727272727272, 13333.333333333334] [80.08008008008008, 106.66666666666667] [2580.6451612903224, 3809.5238095238096, 7272.727272727272, 13333.333333333334] [6153.846153846154, 11428.57142857143]
